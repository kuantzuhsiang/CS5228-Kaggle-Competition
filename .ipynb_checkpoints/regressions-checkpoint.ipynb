# %% [markdown]
# # EDA and Data Pre-processing

# %% [markdown]
# ## Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
import csv
import datetime as dt
import scipy
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import math

# %% [markdown]
# ## Importing Dataset

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %% [markdown]
# ## Pre-processing on Train Dataset

# %% [markdown]
# ## Feature Engineering to Create "dist_mrt" from Auxiliary Data

# %%
# do not change order of this .dropna() function
train.dropna()
train = train.reset_index(drop=True)
train
# Out:
#           month           town flat_type block            street_name  \
# 0       2001-08      pasir ris    4 room   440      pasir ris drive 4
# 1       2014-10        punggol    5-room  196B          punggol field
# 2       2020-09       sengkang    5 room  404A          fernvale lane
# 3       2000-10       clementi    3 room   375      clementi avenue 4
# 4       2013-01    bukit batok    3-room   163  bukit batok street 11
# ...         ...            ...       ...   ...                    ...
# 431727  2005-03      woodlands    4 room   537     Woodlands Drive 16
# 431728  2016-04       sengkang    4 room  410A          fernvale road
# 431729  2011-01       tampines    3-room   829     tampines street 81
# 431730  2013-05       sengkang    5-room   233       compassvale walk
# 431731  2007-08  choa chu kang    4 room   121         Teck Whye Lane
#
#        storey_range  floor_area_sqm         flat_model   eco_category  \
# 0          01 to 03           118.0            model a  uncategorized
# 1          10 to 12           110.0           improved  uncategorized
# 2          01 to 03           112.0  premium apartment  uncategorized
# 3          07 to 09            67.0     new generation  uncategorized
# 4          07 to 09            73.0            model a  uncategorized
# ...             ...             ...                ...            ...
# 431727     01 to 03           101.0            model a  uncategorized
# 431728     13 to 15            95.0  premium apartment  uncategorized
# 431729     01 to 03            67.0     new generation  uncategorized
# 431730     16 to 18           123.0           improved  uncategorized
# 431731     01 to 03           104.0            model a  uncategorized
#
#         lease_commence_date  latitude   longitude  elevation  \
# 0                      1989  1.369008  103.958697        0.0
# 1                      2003  1.399007  103.906991        0.0
# 2                      2004  1.388348  103.873815        0.0
# 3                      1980  1.318493  103.766702        0.0
# 4                      1985  1.348149  103.742658        0.0
# ...                     ...       ...         ...        ...
# 431727                 2000  1.429658  103.792583        0.0
# 431728                 2012  1.390053  103.875941        0.0
# 431729                 1986  1.349224  103.934913        0.0
# 431730                 1999  1.389941  103.900721        0.0
# 431731                 1989  1.378304  103.750108        0.0
#
#                      subzone  planning_area             region  resale_price
# 0            pasir ris drive      pasir ris        east region      209700.0
# 1              punggol field        punggol  north-east region      402300.0
# 2                   fernvale       sengkang  north-east region      351000.0
# 3             clementi north       clementi        west region      151200.0
# 4           bukit batok west    bukit batok        west region      318600.0
# ...                      ...            ...                ...           ...
# 431727       woodlands south      woodlands       north region      238500.0
# 431728              fernvale       sengkang  north-east region      376200.0
# 431729         tampines west       tampines        east region      255600.0
# 431730  sengkang town centre       sengkang  north-east region      508500.0
# 431731             teck whye  choa chu kang        west region      162000.0
#
# [431732 rows x 17 columns]

# %%
with open('./auxiliary-data/distance-to-mrt.csv', newline='') as f:
    reader = csv.reader(f)
    mrt_list = list(reader)

# %%
train['dist_mrt'] = np.array(mrt_list)
train.head()
# Out:
#      month         town flat_type block            street_name storey_range  \
# 0  2001-08    pasir ris    4 room   440      pasir ris drive 4     01 to 03
# 1  2014-10      punggol    5-room  196B          punggol field     10 to 12
# 2  2020-09     sengkang    5 room  404A          fernvale lane     01 to 03
# 3  2000-10     clementi    3 room   375      clementi avenue 4     07 to 09
# 4  2013-01  bukit batok    3-room   163  bukit batok street 11     07 to 09
#
#    floor_area_sqm         flat_model   eco_category  lease_commence_date  \
# 0           118.0            model a  uncategorized                 1989
# 1           110.0           improved  uncategorized                 2003
# 2           112.0  premium apartment  uncategorized                 2004
# 3            67.0     new generation  uncategorized                 1980
# 4            73.0            model a  uncategorized                 1985
#
#    latitude   longitude  elevation           subzone planning_area  \
# 0  1.369008  103.958697        0.0   pasir ris drive     pasir ris
# 1  1.399007  103.906991        0.0     punggol field       punggol
# 2  1.388348  103.873815        0.0          fernvale      sengkang
# 3  1.318493  103.766702        0.0    clementi north      clementi
# 4  1.348149  103.742658        0.0  bukit batok west   bukit batok
#
#               region  resale_price     dist_mrt
# 0        east region      209700.0  1.137651115
# 1  north-east region      402300.0  0.118453389
# 2  north-east region      351000.0  0.479542021
# 3        west region      151200.0  0.421345802
# 4        west region      318600.0  0.775005151

# %% [markdown]
# ## Convert "storey_range" into Numerical Data Type "storey_average"

# %%
# first number in "storey_range"
train['lower_storey'] = train['storey_range'].str.extract('(\d+)').astype(np.uint8)
train['upper_storey'] = train['storey_range'].str.extract('(\d+$)').astype(np.uint8)
# calculate average storey from the range
train['storey_average'] = train['upper_storey'] + train['lower_storey']
train['storey_average'] = train['storey_average'] / 2.0
train = train.drop(columns=['storey_range'])
train.head()
# Out:
#      month         town flat_type block            street_name  \
# 0  2001-08    pasir ris    4 room   440      pasir ris drive 4
# 1  2014-10      punggol    5-room  196B          punggol field
# 2  2020-09     sengkang    5 room  404A          fernvale lane
# 3  2000-10     clementi    3 room   375      clementi avenue 4
# 4  2013-01  bukit batok    3-room   163  bukit batok street 11
#
#    floor_area_sqm         flat_model   eco_category  lease_commence_date  \
# 0           118.0            model a  uncategorized                 1989
# 1           110.0           improved  uncategorized                 2003
# 2           112.0  premium apartment  uncategorized                 2004
# 3            67.0     new generation  uncategorized                 1980
# 4            73.0            model a  uncategorized                 1985
#
#    latitude   longitude  elevation           subzone planning_area  \
# 0  1.369008  103.958697        0.0   pasir ris drive     pasir ris
# 1  1.399007  103.906991        0.0     punggol field       punggol
# 2  1.388348  103.873815        0.0          fernvale      sengkang
# 3  1.318493  103.766702        0.0    clementi north      clementi
# 4  1.348149  103.742658        0.0  bukit batok west   bukit batok
#
#               region  resale_price     dist_mrt  lower_storey  upper_storey  \
# 0        east region      209700.0  1.137651115             1             3
# 1  north-east region      402300.0  0.118453389            10            12
# 2  north-east region      351000.0  0.479542021             1             3
# 3        west region      151200.0  0.421345802             7             9
# 4        west region      318600.0  0.775005151             7             9
#
#    storey_average
# 0             2.0
# 1            11.0
# 2             2.0
# 3             8.0
# 4             8.0

# %% [markdown]
# ## Convert "flat_type" to Ordinal Data Type "flattype_mapping"

# %%
train = train.replace(to_replace ="5 room", value ="5-room")
train = train.replace(to_replace ="4 room", value ="4-room")
train = train.replace(to_replace ="3 room", value ="3-room")
train = train.replace(to_replace ="2 room", value ="2-room")
train = train.replace(to_replace ="1 room", value ="1-room")
flattype_mapping={"1-room": 1,
                   "2-room": 2,
                   "3-room": 3,
                   "4-room": 4,
                   "5-room": 5,
                   "multi generation": 6,
                   "executive": 7,}
train["flattype_mapping"] = train['flat_type'].map(flattype_mapping).astype(np.uint8)
train = train.drop(columns=['flat_type'])
train.head()
# Out:
#      month         town block            street_name  floor_area_sqm  \
# 0  2001-08    pasir ris   440      pasir ris drive 4           118.0
# 1  2014-10      punggol  196B          punggol field           110.0
# 2  2020-09     sengkang  404A          fernvale lane           112.0
# 3  2000-10     clementi   375      clementi avenue 4            67.0
# 4  2013-01  bukit batok   163  bukit batok street 11            73.0
#
#           flat_model   eco_category  lease_commence_date  latitude  \
# 0            model a  uncategorized                 1989  1.369008
# 1           improved  uncategorized                 2003  1.399007
# 2  premium apartment  uncategorized                 2004  1.388348
# 3     new generation  uncategorized                 1980  1.318493
# 4            model a  uncategorized                 1985  1.348149
#
#     longitude  elevation           subzone planning_area             region  \
# 0  103.958697        0.0   pasir ris drive     pasir ris        east region
# 1  103.906991        0.0     punggol field       punggol  north-east region
# 2  103.873815        0.0          fernvale      sengkang  north-east region
# 3  103.766702        0.0    clementi north      clementi        west region
# 4  103.742658        0.0  bukit batok west   bukit batok        west region
#
#    resale_price     dist_mrt  lower_storey  upper_storey  storey_average  \
# 0      209700.0  1.137651115             1             3             2.0
# 1      402300.0  0.118453389            10            12            11.0
# 2      351000.0  0.479542021             1             3             2.0
# 3      151200.0  0.421345802             7             9             8.0
# 4      318600.0  0.775005151             7             9             8.0
#
#    flattype_mapping
# 0                 4
# 1                 5
# 2                 5
# 3                 3
# 4                 3

# %% [markdown]
# ## Convert "region" to Binary Data Type

# %%
one_hot_cols = pd.get_dummies(train, columns=['region'], prefix=['region'])
train = train.merge(one_hot_cols)
train = train.drop(columns=['region'])
train.head()
train['region_central region'] = train['region_central region'].astype(np.uint8)
train['region_east region'] = train['region_central region'].astype(np.uint8)
train['region_north region'] = train['region_central region'].astype(np.uint8)
train['region_north-east region'] = train['region_central region'].astype(np.uint8)
train['region_west region'] = train['region_central region'].astype(np.uint8)

# %% [markdown]
# ## Feature engineering to create "remaining_lease" feature from "lease_commencement_date"

# %%
lease_commence_date = train['lease_commence_date'].to_numpy()
#assuming 99-year lease, we calculate the remaining years on the lease
remaining_lease = lease_commence_date + 99 - pd.DatetimeIndex(train['month']).year.to_numpy()
train['remaining_lease'] = remaining_lease
train = train.drop(columns=['lease_commence_date'])
train.head()
# Out:
#      month         town block            street_name  floor_area_sqm  \
# 0  2001-08    pasir ris   440      pasir ris drive 4           118.0
# 1  2014-10      punggol  196B          punggol field           110.0
# 2  2020-09     sengkang  404A          fernvale lane           112.0
# 3  2000-10     clementi   375      clementi avenue 4            67.0
# 4  2013-01  bukit batok   163  bukit batok street 11            73.0
#
#           flat_model   eco_category  latitude   longitude  elevation  ...  \
# 0            model a  uncategorized  1.369008  103.958697        0.0  ...
# 1           improved  uncategorized  1.399007  103.906991        0.0  ...
# 2  premium apartment  uncategorized  1.388348  103.873815        0.0  ...
# 3     new generation  uncategorized  1.318493  103.766702        0.0  ...
# 4            model a  uncategorized  1.348149  103.742658        0.0  ...
#
#   lower_storey upper_storey  storey_average flattype_mapping  \
# 0            1            3             2.0                4
# 1           10           12            11.0                5
# 2            1            3             2.0                5
# 3            7            9             8.0                3
# 4            7            9             8.0                3
#
#    region_central region  region_east region  region_north region  \
# 0                      0                   0                    0
# 1                      0                   0                    0
# 2                      0                   0                    0
# 3                      0                   0                    0
# 4                      0                   0                    0
#
#    region_north-east region  region_west region  remaining_lease
# 0                         0                   0               87
# 1                         0                   0               88
# 2                         0                   0               83
# 3                         0                   0               79
# 4                         0                   0               71
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Convert "flat_model" to Ordinal Data Type

# %%
flat_models = train.groupby('flat_model')
keys = flat_models.groups.keys()

flat_type_dict = {}

# store the average "resale_price" of each "flat_model" in a dictionary with
#    key : "flat_model"
#    value : average "resale_price"
for key in keys:
    df_i = flat_models.get_group(key)
    flat_type_dict.update({key : df_i["resale_price"].mean()})

# ordering the different "flat_model" by average "resale_price" (ascending order)
{k: v for k, v in sorted(flat_type_dict.items(), key=lambda item: item[1])}
# print(flat_type_dict)
# print(flat_type_dict.keys())

# save the ordered list of keys from dictionary as a list for easier index finding
flat_model_list = list(flat_type_dict.keys())

for flat_model in flat_model_list:
    ordinal_value = flat_model_list.index(flat_model) + 1
    train['flat_model'] = train['flat_model'].str.replace(rf'^{flat_model}$', str(ordinal_value), regex=True)

train['flat_model'] = train['flat_model'].astype(np.uint8)
train.head()
# Out:
#      month         town block            street_name  floor_area_sqm  \
# 0  2001-08    pasir ris   440      pasir ris drive 4           118.0
# 1  2014-10      punggol  196B          punggol field           110.0
# 2  2020-09     sengkang  404A          fernvale lane           112.0
# 3  2000-10     clementi   375      clementi avenue 4            67.0
# 4  2013-01  bukit batok   163  bukit batok street 11            73.0
#
#    flat_model   eco_category  latitude   longitude  elevation  ...  \
# 0           8  uncategorized  1.369008  103.958697        0.0  ...
# 1           5  uncategorized  1.399007  103.906991        0.0  ...
# 2          13  uncategorized  1.388348  103.873815        0.0  ...
# 3          12  uncategorized  1.318493  103.766702        0.0  ...
# 4           8  uncategorized  1.348149  103.742658        0.0  ...
#
#   lower_storey upper_storey  storey_average flattype_mapping  \
# 0            1            3             2.0                4
# 1           10           12            11.0                5
# 2            1            3             2.0                5
# 3            7            9             8.0                3
# 4            7            9             8.0                3
#
#    region_central region  region_east region  region_north region  \
# 0                      0                   0                    0
# 1                      0                   0                    0
# 2                      0                   0                    0
# 3                      0                   0                    0
# 4                      0                   0                    0
#
#    region_north-east region  region_west region  remaining_lease
# 0                         0                   0               87
# 1                         0                   0               88
# 2                         0                   0               83
# 3                         0                   0               79
# 4                         0                   0               71
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Adjust skew on "resale_price"

# %%
boxcox_transform = scipy.stats.boxcox(train['resale_price'])
train['resale_price'] = boxcox_transform[0]
lmbda = train['resale_price'][1]
print(lmbda)
sns.distplot(train['resale_price']);
# Out:
# 42.91070587579928
# C:\Users\tanvi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Convert "month" to DateTime Format

# %%
train_with_data = train.copy()
train['month'] = pd.to_datetime(train['month'])
train['month']=train['month'].map(dt.datetime.toordinal)

# %% [markdown]
# ## Drop Columns "block", "street_name", and "eco_category"

# %%
train = train.drop(columns=['block', 'street_name', 'eco_category'])
train.head()
# Out:
#     month         town  floor_area_sqm  flat_model  latitude   longitude  \
# 0  730698    pasir ris           118.0           8  1.369008  103.958697
# 1  735507      punggol           110.0           5  1.399007  103.906991
# 2  737669     sengkang           112.0          13  1.388348  103.873815
# 3  730394     clementi            67.0          12  1.318493  103.766702
# 4  734869  bukit batok            73.0           8  1.348149  103.742658
#
#    elevation           subzone planning_area  resale_price  ... lower_storey  \
# 0        0.0   pasir ris drive     pasir ris     38.051749  ...            1
# 1        0.0     punggol field       punggol     42.910706  ...           10
# 2        0.0          fernvale      sengkang     41.851105  ...            1
# 3        0.0    clementi north      clementi     35.796573  ...            7
# 4        0.0  bukit batok west   bukit batok     41.112697  ...            7
#
#    upper_storey  storey_average  flattype_mapping  region_central region  \
# 0             3             2.0                 4                      0
# 1            12            11.0                 5                      0
# 2             3             2.0                 5                      0
# 3             9             8.0                 3                      0
# 4             9             8.0                 3                      0
#
#    region_east region  region_north region  region_north-east region  \
# 0                   0                    0                         0
# 1                   0                    0                         0
# 2                   0                    0                         0
# 3                   0                    0                         0
# 4                   0                    0                         0
#
#    region_west region  remaining_lease
# 0                   0               87
# 1                   0               88
# 2                   0               83
# 3                   0               79
# 4                   0               71
#
# [5 rows x 21 columns]

# %%
train = train.drop(columns=['elevation','town','subzone','planning_area'])
train.head()
# Out:
#     month  floor_area_sqm  flat_model  latitude   longitude  resale_price  \
# 0  730698           118.0           8  1.369008  103.958697     38.051749
# 1  735507           110.0           5  1.399007  103.906991     42.910706
# 2  737669           112.0          13  1.388348  103.873815     41.851105
# 3  730394            67.0          12  1.318493  103.766702     35.796573
# 4  734869            73.0           8  1.348149  103.742658     41.112697
#
#       dist_mrt  lower_storey  upper_storey  storey_average  flattype_mapping  \
# 0  1.137651115             1             3             2.0                 4
# 1  0.118453389            10            12            11.0                 5
# 2  0.479542021             1             3             2.0                 5
# 3  0.421345802             7             9             8.0                 3
# 4  0.775005151             7             9             8.0                 3
#
#    region_central region  region_east region  region_north region  \
# 0                      0                   0                    0
# 1                      0                   0                    0
# 2                      0                   0                    0
# 3                      0                   0                    0
# 4                      0                   0                    0
#
#    region_north-east region  region_west region  remaining_lease
# 0                         0                   0               87
# 1                         0                   0               88
# 2                         0                   0               83
# 3                         0                   0               79
# 4                         0                   0               71

# %% [markdown]
# ## Pre-processing on Test Dataset

# %% [markdown]
# ## Feature Engineering to Create "dist_mrt" from Auxiliary Data

# %%
test.dropna()
test = test.reset_index(drop=True)
test
# Out:
#           month             town flat_type block                street_name  \
# 0       2004-01      bukit batok    4 room   186  bukit batok west avenue 6
# 1       2001-11         tampines    5 room   366         tampines street 34
# 2       2002-07      jurong east    3 room   206      jurong east street 21
# 3       2015-04       ang mo kio    3 room   180        Ang Mo Kio Avenue 5
# 4       2004-04         clementi    5 room   356          clementi avenue 2
# ...         ...              ...       ...   ...                        ...
# 107929  2008-04          hougang    5 room  981D          buangkok crescent
# 107930  2006-01  kallang/whampoa    4 room    13       upper boon keng road
# 107931  2000-01  kallang/whampoa    3 room     1                 beach road
# 107932  2009-07      jurong west    4 room   919      jurong west street 91
# 107933  2010-05         sengkang    4-room  201A          Compassvale Drive
#
#        storey_range  floor_area_sqm      flat_model   eco_category  \
# 0          04 to 06            94.0  new generation  uncategorized
# 1          04 to 06           122.0        improved  uncategorized
# 2          01 to 03            67.0  new generation  uncategorized
# 3          04 to 06            82.0  new generation  uncategorized
# 4          01 to 03           117.0        standard  uncategorized
# ...             ...             ...             ...            ...
# 107929     10 to 12           110.0        improved  uncategorized
# 107930     13 to 15           102.0         model a  uncategorized
# 107931     07 to 09            68.0        improved  uncategorized
# 107932     10 to 12           104.0         model a  uncategorized
# 107933     04 to 06            90.0         model a  uncategorized
#
#         lease_commence_date  latitude   longitude  elevation  \
# 0                      1989  1.346581  103.744085        0.0
# 1                      1997  1.357618  103.961379        0.0
# 2                      1982  1.337804  103.741998        0.0
# 3                      1981  1.380084  103.849574        0.0
# 4                      1978  1.313960  103.769831        0.0
# ...                     ...       ...         ...        ...
# 107929                 2003  1.380452  103.879333        0.0
# 107930                 1999  1.314481  103.870458        0.0
# 107931                 1979  1.294924  103.854315        0.0
# 107932                 1988  1.339927  103.687354        0.0
# 107933                 2001  1.389001  103.892763        0.0
#
#                      subzone  planning_area             region
# 0           bukit batok west    bukit batok        west region
# 1              tampines east       tampines        east region
# 2                   toh guan    jurong east        west region
# 3          yio chu kang east     ang mo kio  north-east region
# 4             clementi north       clementi        west region
# ...                      ...            ...                ...
# 107929             trafalgar        hougang  north-east region
# 107930             boon keng        kallang     central region
# 107931             city hall  downtown core     central region
# 107932                yunnan    jurong west        west region
# 107933  sengkang town centre       sengkang  north-east region
#
# [107934 rows x 16 columns]

# %%
with open('./auxiliary-data/distance-to-mrt-test-edited.csv', newline='') as f:
    reader = csv.reader(f)
    mrt_list = list(reader)

# %%
test['dist_mrt'] = np.array(mrt_list)
test.head()
# Out:
#      month         town flat_type block                street_name  \
# 0  2004-01  bukit batok    4 room   186  bukit batok west avenue 6
# 1  2001-11     tampines    5 room   366         tampines street 34
# 2  2002-07  jurong east    3 room   206      jurong east street 21
# 3  2015-04   ang mo kio    3 room   180        Ang Mo Kio Avenue 5
# 4  2004-04     clementi    5 room   356          clementi avenue 2
#
#   storey_range  floor_area_sqm      flat_model   eco_category  \
# 0     04 to 06            94.0  new generation  uncategorized
# 1     04 to 06           122.0        improved  uncategorized
# 2     01 to 03            67.0  new generation  uncategorized
# 3     04 to 06            82.0  new generation  uncategorized
# 4     01 to 03           117.0        standard  uncategorized
#
#    lease_commence_date  latitude   longitude  elevation            subzone  \
# 0                 1989  1.346581  103.744085        0.0   bukit batok west
# 1                 1997  1.357618  103.961379        0.0      tampines east
# 2                 1982  1.337804  103.741998        0.0           toh guan
# 3                 1981  1.380084  103.849574        0.0  yio chu kang east
# 4                 1978  1.313960  103.769831        0.0     clementi north
#
#   planning_area             region     dist_mrt
# 0   bukit batok        west region  0.667553928
# 1      tampines        east region  0.767025394
# 2   jurong east        west region  0.515380197
# 3    ang mo kio  north-east region  0.547114337
# 4      clementi        west region  0.516298405

# %% [markdown]
# ## Convert "month" to DateTime Format

# %%
test['month'] = pd.to_datetime(test['month'])
test['month']=test['month'].map(dt.datetime.toordinal)

# %% [markdown]
# ## Convert "storey_range" into Numerical Data Type "storey_average"

# %%
test['lower_storey'] = test['storey_range'].str.extract('(\d+)').astype(np.uint8)
test['upper_storey'] = test['storey_range'].str.extract('(\d+$)').astype(np.uint8)
# calculate average storey from the range
test['storey_average'] = test['upper_storey'] + test['lower_storey']
test['storey_average'] = test['storey_average'] / 2.0
test = test.drop(columns=['storey_range'])
test.head()
# Out:
#     month         town flat_type block                street_name  \
# 0  731581  bukit batok    4 room   186  bukit batok west avenue 6
# 1  730790     tampines    5 room   366         tampines street 34
# 2  731032  jurong east    3 room   206      jurong east street 21
# 3  735689   ang mo kio    3 room   180        Ang Mo Kio Avenue 5
# 4  731672     clementi    5 room   356          clementi avenue 2
#
#    floor_area_sqm      flat_model   eco_category  lease_commence_date  \
# 0            94.0  new generation  uncategorized                 1989
# 1           122.0        improved  uncategorized                 1997
# 2            67.0  new generation  uncategorized                 1982
# 3            82.0  new generation  uncategorized                 1981
# 4           117.0        standard  uncategorized                 1978
#
#    latitude   longitude  elevation            subzone planning_area  \
# 0  1.346581  103.744085        0.0   bukit batok west   bukit batok
# 1  1.357618  103.961379        0.0      tampines east      tampines
# 2  1.337804  103.741998        0.0           toh guan   jurong east
# 3  1.380084  103.849574        0.0  yio chu kang east    ang mo kio
# 4  1.313960  103.769831        0.0     clementi north      clementi
#
#               region     dist_mrt  lower_storey  upper_storey  storey_average
# 0        west region  0.667553928             4             6             5.0
# 1        east region  0.767025394             4             6             5.0
# 2        west region  0.515380197             1             3             2.0
# 3  north-east region  0.547114337             4             6             5.0
# 4        west region  0.516298405             1             3             2.0

# %% [markdown]
# ## Convert "flat_type" to Ordinal Data Type "flattype_mapping"

# %%
test = test.replace(to_replace ="5 room", value ="5-room")
test = test.replace(to_replace ="4 room", value ="4-room")
test = test.replace(to_replace ="3 room", value ="3-room")
test = test.replace(to_replace ="2 room", value ="2-room")
test = test.replace(to_replace ="1 room", value ="1-room")
flattype_mapping={"1-room": 1,
                   "2-room": 2,
                   "3-room": 3,
                   "4-room": 4,
                   "5-room": 5,
                   "multi generation": 6,
                   "executive": 7,}
test["flattype_mapping"] = test['flat_type'].map(flattype_mapping).astype(np.uint8)
test = test.drop(columns=['flat_type'])
test.head()
# Out:
#     month         town block                street_name  floor_area_sqm  \
# 0  731581  bukit batok   186  bukit batok west avenue 6            94.0
# 1  730790     tampines   366         tampines street 34           122.0
# 2  731032  jurong east   206      jurong east street 21            67.0
# 3  735689   ang mo kio   180        Ang Mo Kio Avenue 5            82.0
# 4  731672     clementi   356          clementi avenue 2           117.0
#
#        flat_model   eco_category  lease_commence_date  latitude   longitude  \
# 0  new generation  uncategorized                 1989  1.346581  103.744085
# 1        improved  uncategorized                 1997  1.357618  103.961379
# 2  new generation  uncategorized                 1982  1.337804  103.741998
# 3  new generation  uncategorized                 1981  1.380084  103.849574
# 4        standard  uncategorized                 1978  1.313960  103.769831
#
#    elevation            subzone planning_area             region     dist_mrt  \
# 0        0.0   bukit batok west   bukit batok        west region  0.667553928
# 1        0.0      tampines east      tampines        east region  0.767025394
# 2        0.0           toh guan   jurong east        west region  0.515380197
# 3        0.0  yio chu kang east    ang mo kio  north-east region  0.547114337
# 4        0.0     clementi north      clementi        west region  0.516298405
#
#    lower_storey  upper_storey  storey_average  flattype_mapping
# 0             4             6             5.0                 4
# 1             4             6             5.0                 5
# 2             1             3             2.0                 3
# 3             4             6             5.0                 3
# 4             1             3             2.0                 5

# %% [markdown]
# ## Convert "region" to Binary Data Type

# %%
one_hot_cols = pd.get_dummies(test, columns=['region'], prefix=['region'])
test = test.merge(one_hot_cols)
test = test.drop(columns=['region'])
test.head()
test['region_central region'] = test['region_central region'].astype(np.uint8)
test['region_east region'] = test['region_central region'].astype(np.uint8)
test['region_north region'] = test['region_central region'].astype(np.uint8)
test['region_north-east region'] = test['region_central region'].astype(np.uint8)
test['region_west region'] = test['region_central region'].astype(np.uint8)

# %% [markdown]
# ## Feature engineering to create "remaining_lease" feature from "lease_commencement_date"

# %%
lease_commence_date = test['lease_commence_date'].to_numpy()
#assuming 99-year lease, we calculate the remaining years on the lease
remaining_lease = lease_commence_date + 99 - pd.DatetimeIndex(test['month']).year.to_numpy()
test['remaining_lease'] = remaining_lease
test = test.drop(columns=['lease_commence_date'])
test.head()
# Out:
#     month         town block                street_name  floor_area_sqm  \
# 0  731581  bukit batok   186  bukit batok west avenue 6            94.0
# 1  730790     tampines   366         tampines street 34           122.0
# 2  731032  jurong east   206      jurong east street 21            67.0
# 3  735689   ang mo kio   180        Ang Mo Kio Avenue 5            82.0
# 4  731672     clementi   356          clementi avenue 2           117.0
#
#        flat_model   eco_category  latitude   longitude  elevation  ...  \
# 0  new generation  uncategorized  1.346581  103.744085        0.0  ...
# 1        improved  uncategorized  1.357618  103.961379        0.0  ...
# 2  new generation  uncategorized  1.337804  103.741998        0.0  ...
# 3  new generation  uncategorized  1.380084  103.849574        0.0  ...
# 4        standard  uncategorized  1.313960  103.769831        0.0  ...
#
#   lower_storey upper_storey storey_average  flattype_mapping  \
# 0            4            6            5.0                 4
# 1            4            6            5.0                 5
# 2            1            3            2.0                 3
# 3            4            6            5.0                 3
# 4            1            3            2.0                 5
#
#    region_central region  region_east region  region_north region  \
# 0                      0                   0                    0
# 1                      0                   0                    0
# 2                      0                   0                    0
# 3                      0                   0                    0
# 4                      0                   0                    0
#
#    region_north-east region  region_west region  remaining_lease
# 0                         0                   0              118
# 1                         0                   0              126
# 2                         0                   0              111
# 3                         0                   0              110
# 4                         0                   0              107
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Convert "flat_model" to Ordinal Data Type

# %%
# uses the same "flat_model_list" extracted from the "flat_model" dictionary calculated from train dataset
for flat_model in flat_model_list:
    ordinal_value = flat_model_list.index(flat_model) + 1
    test['flat_model'] = test['flat_model'].str.replace(rf'^{flat_model}$', str(ordinal_value), regex=True)
    
test['flat_model'] = test['flat_model'].astype(np.uint8)

test.head()
# Out:
#     month         town block                street_name  floor_area_sqm  \
# 0  731581  bukit batok   186  bukit batok west avenue 6            94.0
# 1  730790     tampines   366         tampines street 34           122.0
# 2  731032  jurong east   206      jurong east street 21            67.0
# 3  735689   ang mo kio   180        Ang Mo Kio Avenue 5            82.0
# 4  731672     clementi   356          clementi avenue 2           117.0
#
#    flat_model   eco_category  latitude   longitude  elevation  ...  \
# 0          12  uncategorized  1.346581  103.744085        0.0  ...
# 1           5  uncategorized  1.357618  103.961379        0.0  ...
# 2          12  uncategorized  1.337804  103.741998        0.0  ...
# 3          12  uncategorized  1.380084  103.849574        0.0  ...
# 4          17  uncategorized  1.313960  103.769831        0.0  ...
#
#   lower_storey upper_storey storey_average  flattype_mapping  \
# 0            4            6            5.0                 4
# 1            4            6            5.0                 5
# 2            1            3            2.0                 3
# 3            4            6            5.0                 3
# 4            1            3            2.0                 5
#
#    region_central region  region_east region  region_north region  \
# 0                      0                   0                    0
# 1                      0                   0                    0
# 2                      0                   0                    0
# 3                      0                   0                    0
# 4                      0                   0                    0
#
#    region_north-east region  region_west region  remaining_lease
# 0                         0                   0              118
# 1                         0                   0              126
# 2                         0                   0              111
# 3                         0                   0              110
# 4                         0                   0              107
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Drop Columns "block", "street_name", and "eco_category"

# %%
test = test.drop(columns=['block', 'street_name', 'eco_category'])
test.head()
# Out:
#     month         town  floor_area_sqm  flat_model  latitude   longitude  \
# 0  731581  bukit batok            94.0          12  1.346581  103.744085
# 1  730790     tampines           122.0           5  1.357618  103.961379
# 2  731032  jurong east            67.0          12  1.337804  103.741998
# 3  735689   ang mo kio            82.0          12  1.380084  103.849574
# 4  731672     clementi           117.0          17  1.313960  103.769831
#
#    elevation            subzone planning_area     dist_mrt  lower_storey  \
# 0        0.0   bukit batok west   bukit batok  0.667553928             4
# 1        0.0      tampines east      tampines  0.767025394             4
# 2        0.0           toh guan   jurong east  0.515380197             1
# 3        0.0  yio chu kang east    ang mo kio  0.547114337             4
# 4        0.0     clementi north      clementi  0.516298405             1
#
#    upper_storey  storey_average  flattype_mapping  region_central region  \
# 0             6             5.0                 4                      0
# 1             6             5.0                 5                      0
# 2             3             2.0                 3                      0
# 3             6             5.0                 3                      0
# 4             3             2.0                 5                      0
#
#    region_east region  region_north region  region_north-east region  \
# 0                   0                    0                         0
# 1                   0                    0                         0
# 2                   0                    0                         0
# 3                   0                    0                         0
# 4                   0                    0                         0
#
#    region_west region  remaining_lease
# 0                   0              118
# 1                   0              126
# 2                   0              111
# 3                   0              110
# 4                   0              107

# %%
test = test.drop(columns=['elevation','town','subzone','planning_area'])
test.head()
# Out:
#     month  floor_area_sqm  flat_model  latitude   longitude     dist_mrt  \
# 0  731581            94.0          12  1.346581  103.744085  0.667553928
# 1  730790           122.0           5  1.357618  103.961379  0.767025394
# 2  731032            67.0          12  1.337804  103.741998  0.515380197
# 3  735689            82.0          12  1.380084  103.849574  0.547114337
# 4  731672           117.0          17  1.313960  103.769831  0.516298405
#
#    lower_storey  upper_storey  storey_average  flattype_mapping  \
# 0             4             6             5.0                 4
# 1             4             6             5.0                 5
# 2             1             3             2.0                 3
# 3             4             6             5.0                 3
# 4             1             3             2.0                 5
#
#    region_central region  region_east region  region_north region  \
# 0                      0                   0                    0
# 1                      0                   0                    0
# 2                      0                   0                    0
# 3                      0                   0                    0
# 4                      0                   0                    0
#
#    region_north-east region  region_west region  remaining_lease
# 0                         0                   0              118
# 1                         0                   0              126
# 2                         0                   0              111
# 3                         0                   0              110
# 4                         0                   0              107

# %%
train.head()
# Out:
#     month  floor_area_sqm  flat_model  latitude   longitude  resale_price  \
# 0  730698           118.0           8  1.369008  103.958697     38.051749
# 1  735507           110.0           5  1.399007  103.906991     42.910706
# 2  737669           112.0          13  1.388348  103.873815     41.851105
# 3  730394            67.0          12  1.318493  103.766702     35.796573
# 4  734869            73.0           8  1.348149  103.742658     41.112697
#
#       dist_mrt  lower_storey  upper_storey  storey_average  flattype_mapping  \
# 0  1.137651115             1             3             2.0                 4
# 1  0.118453389            10            12            11.0                 5
# 2  0.479542021             1             3             2.0                 5
# 3  0.421345802             7             9             8.0                 3
# 4  0.775005151             7             9             8.0                 3
#
#    region_central region  region_east region  region_north region  \
# 0                      0                   0                    0
# 1                      0                   0                    0
# 2                      0                   0                    0
# 3                      0                   0                    0
# 4                      0                   0                    0
#
#    region_north-east region  region_west region  remaining_lease
# 0                         0                   0               87
# 1                         0                   0               88
# 2                         0                   0               83
# 3                         0                   0               79
# 4                         0                   0               71

# %% [markdown]
# # Linear Regression implementation for full dataset

# %%
X = train.drop (["resale_price"],axis = 1)
y = train["resale_price"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
print('Training score: {}'.format(regressor.score(X_train, y_train)))
print('Test score: {}'.format(regressor.score(X_test, y_test)))
# Out:
# -1040.4544462506321
# [ 9.23026029e-04  6.99289926e-02  2.20766649e-02 -1.23548558e+01
#   3.91362012e+00 -3.25493898e-01 -9.08472675e-01  9.54884017e-01
#   2.32056707e-02  1.70293488e-01  2.10230483e-01  2.10230483e-01
#   2.10230483e-01  2.10230483e-01  2.10230483e-01  4.95094304e-02]
# Training score: 0.8163080325120476
# Test score: 0.8150541844735633

# %%
y_pred = scipy.special.inv_boxcox(regressor.predict(X_test), lmbda)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df)
print('RMSE for Linear Regression => ',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
#            Actual  Predicted
# 205085  43.136339   1.190568
# 394509  41.344770   1.191148
# 283069  32.452535   1.186599
# 69767   38.552916   1.189519
# 384613  37.805194   1.187303
# ...           ...        ...
# 413904  40.119143   1.189632
# 399764  41.344770   1.190109
# 142745  40.584537   1.189789
# 8845    40.918268   1.190540
# 383030  35.173074   1.186873
#
# [86476 rows x 2 columns]
# RMSE for Linear Regression =>  39.06872813269452

# %%
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = scipy.special.inv_boxcox(regressor.predict(X), lmbda)
df = pd.DataFrame({'Actual': y, 'Predicted': y_pred})
print(df)
# Out:
#            Actual  Predicted
# 0       38.051749   1.188852
# 1       42.910706   1.191827
# 2       41.851105   1.192662
# 3       35.796573   1.186012
# 4       41.112697   1.188629
# ...           ...        ...
# 432371  38.971873   1.188305
# 432372  42.386788   1.191812
# 432373  39.474840   1.188294
# 432374  44.785150   1.192245
# 432375  36.262525   1.188954
#
# [432376 rows x 2 columns]

# %% [markdown]
# # Polynomial regression for full dataset

# %%
poly_reg = PolynomialFeatures(degree = 3)
X_poly = poly_reg.fit_transform(X)
print(len(X_poly))
print(len(y))
# Out:
# 432376
# 432376

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
print('Training score: {}'.format(lin_reg.score(X_poly, y)))
# print('Training score: {}'.format(lin_reg.score(X_test, y_test)))
# Out:
# Training score: 0.8698280104561691

# %%
y_pred = scipy.special.inv_boxcox(lin_reg.predict(X_poly), lmbda)
df = pd.DataFrame({'Real Values':y, 'Predicted Values':y_pred})
print(df)
print('RMSE for Linear Regression => ',np.sqrt(mean_squared_error(y,y_pred)))
# Out:
#         Real Values  Predicted Values
# 0         38.051749          1.188676
# 1         42.910706          1.191665
# 2         41.851105          1.192183
# 3         35.796573          1.185527
# 4         41.112697          1.188993
# ...             ...               ...
# 432371    38.971873          1.188401
# 432372    42.386788          1.191825
# 432373    39.474840          1.188563
# 432374    44.785150          1.191812
# 432375    36.262525          1.189056
#
# [432376 rows x 2 columns]
# RMSE for Linear Regression =>  39.078400668487006

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
steps = [
    ('scalar', StandardScaler()),
    ('poly', PolynomialFeatures(degree=3)),
    ('model', LinearRegression())
]
pipeline = Pipeline(steps)
pipeline.fit(X_train, y_train)
print('Training score: {}'.format(pipeline.score(X_train, y_train)))
print('Test score: {}'.format(pipeline.score(X_test, y_test)))
# Out:
# Training score: 0.9304280228068746
# Test score: 0.9299881280139708

# %%
y_pred_pipeline = scipy.special.inv_boxcox(pipeline.predict(X_test), lmbda)
df = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred_pipeline})
print(df)
mse = mean_squared_error(y_test, y_pred_pipeline)
rmse = math.sqrt(mse)
print('RMSE: {}'.format(rmse))
# Out:
#         Real Values  Predicted Values
# 205085    43.136339          1.190750
# 394509    41.344770          1.190462
# 283069    32.452535          1.184100
# 69767     38.552916          1.188195
# 384613    37.805194          1.187830
# ...             ...               ...
# 413904    40.119143          1.190416
# 399764    41.344770          1.189953
# 142745    40.584537          1.189521
# 8845      40.918268          1.191048
# 383030    35.173074          1.186549
#
# [86476 rows x 2 columns]
# RMSE: 39.06871904981224

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
steps = [
    ('scalar', StandardScaler()),
    ('poly', PolynomialFeatures(degree=4)),
    ('model', LinearRegression())
]
pipeline = Pipeline(steps)
pipeline.fit(X_train, y_train)
print('Training score: {}'.format(pipeline.score(X_train, y_train)))
print('Test score: {}'.format(pipeline.score(X_test, y_test)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-65e296e7a281> in <module>
#       7 ]
#       8 pipeline = Pipeline(steps)
# ----> 9 pipeline.fit(X_train, y_train)
#      10 print('Training score: {}'.format(pipeline.score(X_train, y_train)))
#      11 print('Test score: {}'.format(pipeline.score(X_test, y_test)))
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     333             if self._final_estimator != 'passthrough':
#     334                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 335                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     336
#     337         return self
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     642
#     643         if force_all_finite:
# --> 644             _assert_all_finite(array,
#     645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      87     # safely to reduce dtype induced overflows.
#      88     is_float = X.dtype.kind in 'fc'
# ---> 89     if is_float and (np.isfinite(_safe_accumulator_op(np.sum, X))):
#      90         pass
#      91     elif is_float:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\extmath.py in _safe_accumulator_op(op, x, *args, **kwargs)
#     709         result = op(x, *args, **kwargs, dtype=np.float64)
#     710     else:
# --> 711         result = op(x, *args, **kwargs)
#     712     return result
#     713
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2239         return res
#    2240
# -> 2241     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2242                           initial=initial, where=where)
#    2243
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# KeyboardInterrupt:

# %%
y_pred_pipeline = scipy.special.inv_boxcox(pipeline.predict(X_test), lmbda)
df = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred_pipeline})
print(df)
mse = mean_squared_error(y_test, y_pred_pipeline)
rmse = math.sqrt(mse)
print('RMSE: {}'.format(rmse))

# %% [markdown]
# # Split for 3 periods

# %%
train_with_data = train_with_data.drop(columns=['elevation','town','subzone','planning_area','block', 'street_name', 'eco_category'])
train_with_data.head()

# %% [markdown]
# Splitting data

# %%
train_first = train_with_data[train_with_data['month']< '2007-01']
train_second = train_with_data[train_with_data['month'] > '2007-01']
train_second = train_second[train_second['month']< '2013-01']
train_third = train_with_data[train_with_data['month']>'2013-01']

# %% [markdown]
# convert date to dataframe format

# %%
train_first['month'] = pd.to_datetime(train_first['month'])
train_first['month']=train_first['month'].map(dt.datetime.toordinal)
train_second['month'] = pd.to_datetime(train_second['month'])
train_second['month']=train_second['month'].map(dt.datetime.toordinal)
train_third['month'] = pd.to_datetime(train_third['month'])
train_third['month']=train_third['month'].map(dt.datetime.toordinal)

# %% [markdown]
# train first dataset

# %%
X = train_first.drop (["resale_price"],axis = 1)
y = train_first["resale_price"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print('Training score: {}'.format(regressor.score(X_train, y_train)))
print('Test score: {}'.format(regressor.score(X_test, y_test)))
y_pred = scipy.special.inv_boxcox(regressor.predict(X_test), lmbda)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df)
print('RMSE for Linear Regression=>',np.sqrt(mean_squared_error(y_test,y_pred)))

# %%
steps = [
    ('scalar', StandardScaler()),
    ('poly', PolynomialFeatures(degree=4)),
    ('model', LinearRegression())
]

pipeline = Pipeline(steps)

pipeline.fit(X_train, y_train)

print('Training score: {}'.format(pipeline.score(X_train, y_train)))
print('Test score: {}'.format(pipeline.score(X_test, y_test)))

# %%
y_pred_pipeline = scipy.special.inv_boxcox(pipeline.predict(X_test), lmbda)
df = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred_pipeline})
print(df)
mse = mean_squared_error(y_test, y_pred_pipeline)
rmse = math.sqrt(mse)
print('RMSE: {}'.format(rmse))

# %% [markdown]
# train second dataset

# %%
X = train_second.drop (["resale_price"],axis = 1)
y = train_second["resale_price"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print('Training score: {}'.format(regressor.score(X_train, y_train)))
print('Test score: {}'.format(regressor.score(X_test, y_test)))
y_pred = scipy.special.inv_boxcox(regressor.predict(X_test),lmbda)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df)
print('RMSE for Linear Regression=>',np.sqrt(mean_squared_error(y_test,y_pred)))

# %%
steps = [
    ('scalar', StandardScaler()),
    ('poly', PolynomialFeatures(degree=4)),
    ('model', LinearRegression())
]

pipeline = Pipeline(steps)

pipeline.fit(X_train, y_train)

print('Training score: {}'.format(pipeline.score(X_train, y_train)))
print('Test score: {}'.format(pipeline.score(X_test, y_test)))

# %%
y_pred_pipeline = scipy.special.inv_boxcox(pipeline.predict(X_test),lmbda)
df = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred_pipeline})
print(df)
mse = mean_squared_error(y_test, y_pred_pipeline)
rmse = math.sqrt(mse)
print('RMSE: {}'.format(rmse))

# %% [raw]
# train third dataset

# %%
X = train_second.drop (["resale_price"],axis = 1)
y = train_second["resale_price"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print('Training score: {}'.format(regressor.score(X_train, y_train)))
print('Test score: {}'.format(regressor.score(X_test, y_test)))
y_pred = scipy.special.inv_boxcox(regressor.predict(X_test), lmbda)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df)
print('RMSE for Linear Regression=>',np.sqrt(mean_squared_error(y_test,y_pred)))

# %%
steps = [
    ('scalar', StandardScaler()),
    ('poly', PolynomialFeatures(degree=4)),
    ('model', LinearRegression())
]

pipeline = Pipeline(steps)

pipeline.fit(X_train, y_train)

print('Training score: {}'.format(pipeline.score(X_train, y_train)))
print('Test score: {}'.format(pipeline.score(X_test, y_test)))

# %%
y_pred_pipeline = scipy.special.inv_boxcox(pipeline.predict(X_test),lmbda)
df = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred_pipeline})
print(df)
mse = mean_squared_error(y_test, y_pred_pipeline)
rmse = math.sqrt(mse)
print('RMSE: {}'.format(rmse))
